# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # 최종 미션
#
# flights 데이터 셋으로 seaborn기술문서 확인 후에 2개 정도의 chart 그리기
# 이미지 화 해서 오늘 구글 디렉토리에 이름1 이름2로 저장하기

# %%
flights_long
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
ax = sns.swarmplot(data=flights_long, x="year", y="month", hue="passengers")

# %%
sns.relplot(data=flights_long, x="year", y="passengers", hue="month", kind="line")

# %%
sns.relplot(data=flights_long, x="month", y="passengers", hue="year", kind="line")

# %%
flights_wide = flights_long.pivot(index="year", columns="month", values="passengers")
sns.catplot(data=flights_wide, kind="box")

# %%
flights_avg = flights_long.groupby("year").mean()
sns.relplot(data=flights_avg, x="year", y="passengers", kind="line")
